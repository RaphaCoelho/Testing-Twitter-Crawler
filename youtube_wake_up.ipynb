# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import tweepy
import datetime
import xlsxwriter
import sys

# credentials from https://apps.twitter.com/
consumerKey = "Z5ED4uP92bOEqHoiuk29kmRXu"
consumerSecret = "fLjniOxSK64ottxOSMgV1XlQzpWpGZ1qlvlcD4EirJqzR0if7I"
accessToken = "710110177190670338-Jm3IHU9eQxT56AysessEyANFwhpXquL "
accessTokenSecret = "wfiMkoicQBmlTHgQeizx4MFox4VSkQhlDhsZYjCpWhWtm "

auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)

api = tweepy.API(auth)

username = sys.argv[1]
startDate = datetime.datetime(2019, 2, 20, 0, 0, 0)
endDate =   datetime.datetime(2019, 2, 23, 0, 0, 0)

tweets = []
tmpTweets = api.user_timeline(username)
for tweet in tmpTweets:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        tweets.append(tweet)

while (tmpTweets[-1].created_at > startDate):
    print("Last Tweet @", tmpTweets[-1].created_at, " - fetching some more")
    tmpTweets = api.user_timeline(username, max_id = tmpTweets[-1].id)
    for tweet in tmpTweets:
        if tweet.created_at < endDate and tweet.created_at > startDate:
            tweets.append(tweet)

# %%
#!/usr/bin/python
import tweepy
import csv #Import csv
auth = tweepy.auth.OAuthHandler('Z5ED4uP92bOEqHoiuk29kmRXu', 'fLjniOxSK64ottxOSMgV1XlQzpWpGZ1qlvlcD4EirJqzR0if7I')
auth.set_access_token('710110177190670338-Jm3IHU9eQxT56AysessEyANFwhpXquL', 'wfiMkoicQBmlTHgQeizx4MFox4VSkQhlDhsZYjCpWhWtm')

api = tweepy.API(auth)

# Open/create a file to append data to
csvFile = open('result.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,
                           q = "youtubewakeup",
                           since = "2019-02-20",
                           until = "2019-02-24",
                           ).items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.id_str, tweet.lang, tweet.place])
    print(tweet.created_at, tweet.text, tweet.id_str, tweet.lang, tweet.place)
csvFile.close()
# Out:
# 2019-02-23 23:59:54 @pewdiepie Today I thank @elonmusk for doing his part in my new video....Thank you Elon musk… https://t.co/jy4aUxDXR7 1099458862971830272 en None
# 2019-02-23 23:59:27 RT @_bew1tched: The amount of YouTubers who are upset about YouTube disabling comments makes me cringe. It's a temporary solution to a horr… 1099458750337900544 en None
# 2019-02-23 23:54:51 triste #YoutubeWakeUp 😔💔 1099457590122156032 es None
# 2019-02-23 23:53:20 RT @Tangleofshadows: WTF @YouTubeEspanol ¿qué está pasando con la pedofilia en YT?
#
# Me ha costado 3 clicks llegar al warmhole del que se ha… 1099457209413586954 es None
# 2019-02-23 23:52:56 @RatadehieloYT Eso que decís está perfecto pero igual YouTube como empresa tiene que tomar medidas contra la pedofilia #youtubewakeup 1099457109253648385 es None
# 2019-02-23 23:52:40 #YouTubeWakeUp los tiempos cambian. https://t.co/h5ZLUACQXk 1099457041041637376 es None
# 2019-02-23 23:51:41 RT @HiggsBosonMusic: Top Tracks – Higgs Boson
#
# ...

# %%
#!/usr/bin/python
import tweepy
import csv #Import csv
auth = tweepy.auth.OAuthHandler('Z5ED4uP92bOEqHoiuk29kmRXu', 'fLjniOxSK64ottxOSMgV1XlQzpWpGZ1qlvlcD4EirJqzR0if7I')
auth.set_access_token('710110177190670338-Jm3IHU9eQxT56AysessEyANFwhpXquL', 'wfiMkoicQBmlTHgQeizx4MFox4VSkQhlDhsZYjCpWhWtm')

api = tweepy.API(auth)

# Open/create a file to append data to
csvFile = open('result20-24.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

api = tweepy.API(auth, wait_on_rate_limit=True)

for tweet in tweepy.Cursor(api.search,
                           q = "youtubewakeup",
                           since = "2019-02-20",
                           until = "2019-02-25",
                           ).items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.id_str, tweet.lang, tweet.place])
    print(tweet.created_at, tweet.text, tweet.id_str, tweet.lang, tweet.place)
csvFile.close()
# Out:
# 2019-02-24 23:53:01 RT @iludidaa_r: Sinceramente, QUE NOJO! Parece que brota macho escroto do chão, por favor RT, ajuda mto ❤ #YoutubeWakeup https://t.co/cgkqA… 1099819519730769922 pt None
# 2019-02-24 23:48:15 RT @writerlane: This is the livestream version of what the viral video was saying is an issue on Youtube. Taken one minute ago.  @youtube,… 1099818319148929027 en None
# 2019-02-24 23:47:06 RT @mariskabadass: Acabei de ver o vídeo do felipe neto. É perturbador o quanto de pedófilo  que tem no youtube e saber que os responsáveis… 1099818031373582336 pt None
# 2019-02-24 23:38:21 @mmmwhatchyasayy What shocked me those most about @youtubewakeup and now your post is how brazen the commenters/buy… https://t.co/EBM9EXe5fh 1099815827782668290 en None
# 2019-02-24 23:35:13 @mmmwhatchyasayy Have you been following this @youtubewakeup? I've been slowly working on material for revenge porn… https://t.co/0ASQFq8f1d 1099815038670516224 en None
# ...

# %%
#!/usr/bin/python
import tweepy
import csv #Import csv
auth = tweepy.auth.OAuthHandler('Z5ED4uP92bOEqHoiuk29kmRXu', 'fLjniOxSK64ottxOSMgV1XlQzpWpGZ1qlvlcD4EirJqzR0if7I')
auth.set_access_token('710110177190670338-Jm3IHU9eQxT56AysessEyANFwhpXquL', 'wfiMkoicQBmlTHgQeizx4MFox4VSkQhlDhsZYjCpWhWtm')

api = tweepy.API(auth)

# Open/create a file to append data to
csvFile = open('result25-26.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

api = tweepy.API(auth, wait_on_rate_limit=True)

for tweet in tweepy.Cursor(api.search,
                           q = "youtubewakeup",
                           since = "2019-02-25",
                           until = "2019-02-27",
                           ).items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.id_str, tweet.lang, tweet.place])
    print(tweet.created_at, tweet.text, tweet.id_str, tweet.lang, tweet.place)
csvFile.close()
# Out:
# 2019-02-26 23:54:50 RT @catalisando: Youtube está Facilitando a Exploração Sexual de Crianças, e está sendo Monetizado (2019) (https://t.co/XZsECp2PgH)
#
# #YouTu… 1100544750820704256 pt None
# 2019-02-26 23:53:25 #YoutubeWakeUp 1100544395873607681 und Place(_api=<tweepy.api.API object at 0x000001FC25C34E48>, id='97bcdfca1a2dca59', url='https://api.twitter.com/1.1/geo/id/97bcdfca1a2dca59.json', place_type='city', name='Rio de Janeiro', full_name='Rio de Janeiro, Brazil', country_code='BR', country='Brazil', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x000001FC25C34E48>, type='Polygon', coordinates=[[[-43.795449, -23.08302], [-43.0877068, -23.08302], [-43.0877068, -22.7398234], [-43.795449, -22.7398234]]]), attributes={})
# 2019-02-26 23:51:40 cara, assistam o vídeo do @felipeneto.. e @youtube, in Jesus name, faz alguma coisa! #youtubewakeup 1100543953068281858 pt None
# ...

# %%
#!/usr/bin/python
import tweepy
import csv #Import csv
auth = tweepy.auth.OAuthHandler('Z5ED4uP92bOEqHoiuk29kmRXu', 'fLjniOxSK64ottxOSMgV1XlQzpWpGZ1qlvlcD4EirJqzR0if7I')
auth.set_access_token('710110177190670338-Jm3IHU9eQxT56AysessEyANFwhpXquL', 'wfiMkoicQBmlTHgQeizx4MFox4VSkQhlDhsZYjCpWhWtm')

api = tweepy.API(auth)

# Open/create a file to append data to
csvFile = open('result27-01.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

api = tweepy.API(auth, wait_on_rate_limit=True)

for tweet in tweepy.Cursor(api.search,
                           q = "youtubewakeup",
                           since = "2019-02-27",
                           until = "2019-03-02",
                           ).items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.id_str, tweet.lang, tweet.place])
    print(tweet.created_at, tweet.text, tweet.id_str, tweet.lang, tweet.place)
csvFile.close()
# Out:
# 2019-03-01 23:54:46 RT @anni_ful: Be angry at pedophiles. Be angry at @YouTube
#
# Don't be angry at people who call out pedophiles and @YouTube
#
# Fucking disappo… 1101631896818249728 en None
# 2019-03-01 23:27:28 RT @camzsing: JA CANSEI DE VER ISSO ACONTECENDO NO MUNDO E NINGUÉM ACORDAR, AGORA VAMO ACORDAR YOUTUBE E AJUDAR PRENDER ESSES ESCROTOS! ISS… 1101625028272160768 pt None
# 2019-03-01 23:27:27 RT @tess_ao: [+18!!!] O maior problema do Youtube. É muito sério. https://t.co/iPycNNXb2z via @YouTube
# #YOUTUBEWAKEUP
# POR FAVOR ASSISTAM ES… 1101625024266547200 pt None
# 2019-03-01 23:12:45 RT @Jimmy_Hanyu: de coração agora. eu sei que é o felipe neto, e ninguém costuma dar muita moral pra ele, mas esse vídeo deveria ser visto… 1101621326081638400 pt None
# 2019-03-01 23:08:55 RT @Jimmy_Hanyu: de coração agora. eu sei que é o felipe neto, e ninguém costuma dar muita moral pra ele, mas esse vídeo deveria ser visto… 1101620360167022592 pt None
# ...

# %%
#!/usr/bin/python
import tweepy
import csv #Import csv
auth = tweepy.auth.OAuthHandler('Z5ED4uP92bOEqHoiuk29kmRXu', 'fLjniOxSK64ottxOSMgV1XlQzpWpGZ1qlvlcD4EirJqzR0if7I')
auth.set_access_token('710110177190670338-Jm3IHU9eQxT56AysessEyANFwhpXquL', 'wfiMkoicQBmlTHgQeizx4MFox4VSkQhlDhsZYjCpWhWtm')

api = tweepy.API(auth)

# Open/create a file to append data to
csvFile = open('result27-01-teste.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

api = tweepy.API(auth, wait_on_rate_limit=True)

for tweet in tweepy.Cursor(api.search,
                           q = "youtubewakeup",
                           since = "2019-02-26",
                           until = "2019-02-28",
                           ).items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.id_str, tweet.lang, tweet.place])
    print(tweet.created_at, tweet.text, tweet.id_str, tweet.lang, tweet.place)
csvFile.close()
# Out:
# 2019-02-27 23:59:27 RT @SpencerKarter: #FireSusan #Petition #Update: Please Sign @RamosRazviel's Petition to Bring Back @Chad_Hurley! https://t.co/8Gn2LLoAz2 v… 1100908299489300480 en None
# 2019-02-27 23:56:12 RT @alternatescene: @SupportFeNeto @felipeneto O que fazer depois de ler esse pedido de socorro nos comentários do vídeo? @felipeneto #yout… 1100907482443104256 pt None
# 2019-02-27 23:55:02 #FireSusan #Petition #Update: Please Sign @RamosRazviel's Petition to Bring Back @Chad_Hurley!… https://t.co/wwtxGJE9Bb 1100907190100127756 en None
# 2019-02-27 23:49:36 PATENTS PLS READ AND KEEP YOUR KID'S AWAY FROM @YouTube @YTCreators #MomoChallenge #MOMO #YouTubeWakeUp #YouTube… https://t.co/tsw5DARzjB 1100905821167370243 en None
# 2019-02-27 23:49:14 RT @MaDaMBu06332773: WTAF!! #chrisingham #sarahingham PROTECT YOUR CHILDREN!! @youtube @TeamYouTube These comments could be from ANYBODY !!… 1100905729475649536 en None
# 2019-02-27 23:42:36 #YouTubeWakeUp 1100904061551947783 und None
# ...
